# %%
import pandas as pd

# %%
df = pd.read_csv("jiji_car_dataset.csv")
df.head(20)
# Out:
#                                                 title        make     model  \
# 0                         Lexus RX 350 FWD 2013 White       Lexus        RX
# 1                             Lexus RX 300 2003 Green       Lexus        RX
# 2              Volkswagen Tiguan S 4Motion 2010 White  Volkswagen    Tiguan
# 3                             Toyota Hilux 2020 White      Toyota     Hilux
# 4   Toyota Camry LE V6 4dr Sedan (3.5L 6cyl 6AM) 2...      Toyota     Camry
# 5         Mercedes-Benz GLK-Class 350 4MATIC 2013 Red         NaN       NaN
# 6                   Honda Accord Crosstour 2012 White       Honda    Accord
# 7          Mercedes-Benz GLE-Class GLE 350 2016 Black         NaN       NaN
# 8                      Toyota Sienna LE 4WD 2007 Gold      Toyota    Sienna
# 9                            Lexus RX 350 2010 Silver       Lexus        RX
# 10                             Toyota Hilux 2019 Gray      Toyota     Hilux
# ...
